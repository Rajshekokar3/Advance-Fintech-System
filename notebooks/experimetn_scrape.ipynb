# %%
import nselib
from nselib import capital_market
import requests
from bs4 import BeautifulSoup
import time

# %%
holiday_cal=nselib.trading_holiday_calendar()

# %%
holiday_cal.head(5)

# %%
nse_company=capital_market.bhav_copy_equities('16-12-2025')

# %%
nse_company.columns

# %%
nse_work=nse_company[['TradDt','BizDt','TckrSymb','SctySrs','XpryDt','OpnPric','HghPric','LwPric','ClsPric','LastPric']]

# %%
## Real time price extraction
nse_url='https://www.google.com/finance/quote/INFY:NSE'
bse_url='https://www.google.com/finance/quote/500209:BOM'

# %%
import requests
from bs4 import BeautifulSoup
import time

ticker='RELIANCE'
nse_url=f'https://www.google.com/finance/quote/{ticker}:NSE'
response=requests.get(nse_url)

soup=BeautifulSoup(response.text,'html.parser')
# Price real time 
class1='YMlKec fxKbKc'
price=float(soup.find(class_=class1).text.strip()[1:].replace(",",''))
price

# %% [markdown]
# ## News collection

# %%
import requests

ticker='RELIANCE'
url = "https://gnews.io/api/v4/search"
params = {
    "q": f"{ticker} latest news",
    "lang": "en",
    "country": "in",
    "max": 50,
    "apikey": "ea54132ae726450e8b7810641a5ac4e5"
}
res = requests.get(url, params=params)
articles = res.json()["articles"]

print(articles[0]["content"])
# Out:
# Shares of Reliance Power got a sentiment boost after the Mumbai Bench of the Income Tax Appellate Tribunal (ITAT) dismissed the Income-tax Department’s appeal, upholding relief granted to the company on a Section 14A disallowance. According to a Taxs... [2755 chars]

# %%
print("Title:", articles[0]["title"])
print("Content:", articles[0]["content"])
print("Source URL:", articles[0]["url"])
# Out:
# Title: Anil Ambani’s Reliance Power Shares Rise After ITAT Reduces Tax Demand from ₹99 Cr to ₹7.33 Cr
# Content: Shares of Reliance Power got a sentiment boost after the Mumbai Bench of the Income Tax Appellate Tribunal (ITAT) dismissed the Income-tax Department’s appeal, upholding relief granted to the company on a Section 14A disallowance. According to a Taxs... [2755 chars]
# Source URL: https://www.lokmattimes.com/business/anil-ambanis-reliance-power-shares-rise-after-itat-reduces-tax-demand-from-rs99-cr-to-rs733-cr-a475/

# %%
articles
# Out:
# [{'id': '063772599b7497e2dbaa08ada0a6ccde',
#   'title': 'Reliance Jewels brings back Dream Diamond sale with a free gold coin offer',
#   'description': 'Reliance Jewels brings back Dream Diamond sale with a free gold coin offer - Mumbai (Maharashtra) [India], December 22 : Reliance Jewels, a part of Reliance Retail Ltd., brings back its Dream Diamond ... Get Latest News on Entertainment only on lokmattimes.com',
#   'content': 'Mumbai (Maharashtra) [India], December 22 : Reliance Jewels, a part of Reliance Retail Ltd., brings back its Dream Diamond Sale, offering shoppers an attractive and inviting way to celebrate the season.\nThe sale arrives at a time when people are choo... [1462 chars]',
#   'url': 'https://www.lokmattimes.com/entertainment/reliance-jewels-brings-back-dream-diamond-sale-with-a-free-gold-coin-offer/',
#   'image': 'https://d3pc1xvrcw35tl.cloudfront.net/ln
z',
#   'lang': 'en',
#   'source': {'id': 'f2ddccedc9e60d844e7a1045928cad48',
#    'name': 'Lokmat Times',
#    'url': 'https://www.lokmattimes.com',
#    'country': 'in'}},
#  {'id': '88a1ea27e6e5cafe2a1ce7dc45e6affb',
#   'title': 'What is SHANTI Bill, 2025, how can it help India achieve self',
#   'description': 'What is SHANTI Bill, 2025, how can it help India achieve self-reliance in nuclear energy - New Delhi, Dec 19 The Sustainable Harnessing and Advancement of Nuclear Energy for Transforming India (SHANTI) Bill, 2025, ... Get Latest News on National only on lokmattimes.com',
#   'content': 'New Delhi, Dec 19 The Sustainable Harnessing and Advancement of Nuclear Energy for Transforming India (SHANTI) Bill, 2025, passed by both Lok Sabha and Rajya Sabha, aims to achieve self-reliance in the nuclear sector and meet India’s 2047 clean energ... [4507 chars]',
#   'url': 'https://www.lokmattimes.com/national/what-is-shanti-bill-2025-how-can-it-help-india-achieve-self-reliance-in-nuclear-energy/',
#   'image': 'https://d3pc1xvrcw35tl.cloudfront.net/ln/feedImages/1200x900/202512193612742_202512.jpg',
#   'publishedAt': '2025-12-19T08:58:57Z',
#   'lang': 'en',
#   'source': {'id': 'f2ddccedc9e60d844e7a1045928cad48',
#    'name': 'Lokmat Times',
#    'url': 'https://www.lokmattimes.com',
#    'country': 'in'}},
#  {'id': 'ae23a379c69382a5477e9bce0e8037bd',
#   'title': 'Anil Ambani’s Reliance Power, Reliance Infra Shares Shine as Stock Hits Upper Circuit for Fifth Straight Day',
#   'description': 'Anil Ambani’s Reliance Power, Reliance Infra Shares Shine as Stock Hits Upper Circuit for Fifth Straight Day - Anil Ambani’s Reliance Infrastructure Ltd and Reliance Power has kept \xa0its momentum on the Bombay Stock Exchange (BSE) and ... Get Latest News on Business only on lokmattimes.com',
#   'content': 'Anil Ambani’s Reliance Infrastructure Ltd and Reliance Power has kept its momentum on the Bombay Stock Exchange (BSE) and the NSE for the fourth consecutive day on Friday. The ADA Group stocks continued to attract strong investor interest, delivering... [1946 chars]',
#   'url': 'https://www.lokmattimes.com/business/anil-ambanis-reliance-power-reliance-infra-shares-shine-as-stock-hits-upper-circuit-for-fifth-straight-day-a475/',
#   'image': 'https://d3pc1xvrcw35tl.cloudfront.net/ln/images/1200x900/anil-ambani-reliance-power-share-price-reliance-infra-share-price-stock-market-news_2025121060959.jpg',
#   'publishedAt': '2025-12-19T06:10:27Z',
#   'lang': 'en',
#   'source': {'id': 'f2ddccedc9e60d844e7a1045928cad48',
#    'name': 'Lokmat Times',
#    'url': 'https://www.lokmattimes.com',
#    'country': 'in'}}]

# %%
titles=[]
Content=[]
Source_URL=[]
news_data={}
for i in range(len(articles)):
    Source_URL.append(articles[i]["url"])
    titles.append(articles[i]["title"])
    Content.append(articles[i]["content"])

# %%
Content
# Out:
# ['Mumbai (Maharashtra) [India], December 22 : Reliance Jewels, a part of Reliance Retail Ltd., brings back its Dream Diamond Sale, offering shoppers an attractive and inviting way to celebrate the season.\nThe sale arrives at a time when people are choo... [1462 chars]',
#  'Shares of Anil Ambani’s Reliance Power tumbled 7% during Monday’s trading session, following the trading suspension of its group company, Reliance Infrastructure. Investors faced limited exit options as Reliance Infra hit the upper circuit, prompting... [4735 chars]',
#  'In a major setback for the Anil Ambani-led ADAG group, Reliance Infrastructure has been admitted into the Insolvency Resolution Process (IRP) under the Insolvency and Bankruptcy Code (IBC). Following this development, stock exchanges have placed the ... [3411 chars]',
#  'Stating that the National Capital Region (NCR) required a robust public transport system with last-mile connectivity, Gupta said her government was working towards a reliable, extensive and convenient public transport network.\n“The data from the Cent... [1878 chars]',
